# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %% [markdown]
# ## Create Dataset 2D Gaussian

# %%
from sklearn.datasets import make_blobs

# %%
X, y = make_blobs(100, 2, centers=2, random_state=2, cluster_std=1.5)
plt.scatter(X[:, 0], X[:, 1], c=y, cmap='RdBu')

# %%
plt.scatter(X[:, 0], X[:, 1], cmap='RdBu')
# Out:
# <ipython-input-5-f5386e504ef1>:1: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(X[:, 0], X[:, 1], cmap='RdBu')

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(X, y)
# Out:
# GaussianNB()

# %%
rng = np.random.RandomState(0)
Xnew = [-6, -14] + [14, 18] * rng.rand(2000, 2)
plt.scatter(Xnew[:, 0], Xnew[:, 1], cmap='RdBu')
# Out:
# <ipython-input-9-b660fecbc4b0>:3: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(Xnew[:, 0], Xnew[:, 1], cmap='RdBu')

# %%
ynew = model.predict(Xnew)

# %%
plt.scatter(X[:, 0], X[:, 1], c=y, cmap='RdBu')
plt.scatter(Xnew[:, 0], Xnew[:, 1], c=ynew, cmap='RdBu', alpha=0.1)
